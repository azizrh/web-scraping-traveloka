# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys

import bs4
from bs4 import BeautifulSoup

import requests
import pandas as pd
import time
import numpy as np

# %%
#appending data frame to existing excel file
def append_df_to_excel(df, excel_path):
    df_excel = pd.read_excel(excel_path)
    result = pd.concat([df_excel, df], ignore_index=True)
    result.to_excel(excel_path, index=False)

# %%
# #reading provinces list
# read_province_list = open("jawa_bali.txt",'r')
# provinces=[]
# # # for _ in range(33): #skipping province
# # #     next(read_province_list)
# for province in read_province_list:
#     provinces.append(province.replace("\n", ", Indonesia").strip())

# # provinces[33]+=", Indonesia"
# # provinces = pd.read_excel(r"Indonesias_Hotel_List.xlsx",usecols=[2],skiprows=[0]).drop_duplicates().values.tolist()


# #provinces=[provinces[44]]
# print((provinces))

# %%
kota = pd.read_csv(r"Indonesian_Family_Life_Survey_4_Longitude_and_Latitude.csv", usecols=[5,6]).drop_duplicates()
len(kota)
for j in range(99,102):
    print(kota.iloc[j,1])
# Out:
# PANGKAL PINANG
# BATAM
# JAKARTA SELATAN

# %%
#url link
my_url='https://www.traveloka.com/en-id/'


#calling web driver from its directory
s=Service(r'C:\Users\62811\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe') 


def strip(x):
    if x !=None:
        return   str(x.text.strip())
    else:
        return str('')

# %%
#url link
my_url='https://www.traveloka.com/en-id/'


#calling web driver from its directory
s=Service(r'C:\Users\62811\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe') 

city=["Enak banget loh","Jakarta","Bandung"]
for i in range(len(city)):
    try:
        driver = webdriver.Firefox(service=s)
        wait = WebDriverWait(driver, 30)
        driver.get(my_url)
        search_box = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[data-testid='autocomplete-field']"))).send_keys(city[i])

        #(wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name' and *contains(string(), %s)]"%city)))).click()
        auto_complete = wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name'][1]")))
        auto_complete.click()
        wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "[data-testid='search-submit-button']"))).click()



        x=''
        while True:
            try:
                time.sleep(4)
                x = x + wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "_2qd8A"))).get_attribute('innerHTML') #find_elements_by_class_name("_7192d3184")
                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID,"next-button"))).click()
                print("Clicked on  Next Page »")
            except TimeoutException:
                print("No more Next Page »")
                break
        driver.quit()

        card=BeautifulSoup(x, 'html.parser').find_all(True,{'class':'ztzlF _2nyWi'})
    except TimeoutException:
        driver.quit()
        continue






    import winsound
    duration = 1000  # milliseconds
    freq = 300  # Hz
    winsound.Beep(freq, duration)
# Out:
# Clicked on  Next Page »
# Clicked on  Next Page »
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10548/2851838318.py in <module>
#      25             try:
#      26                 time.sleep(4)
# ---> 27                 x = x + wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "_2qd8A"))).get_attribute('innerHTML') #find_elements_by_class_name("_7192d3184")
#      28                 WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID,"next-button"))).click()
#      29                 print("Clicked on  Next Page »")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      76         while True:
#      77             try:
# ---> 78                 value = method(self._driver)
#      79                 if value:
#      80                     return value
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\support\expected_conditions.py in _predicate(driver)
#     123     def _predicate(driver):
#     124         try:
# --> 125             return _element_if_visible(driver.find_element(*locator))
#     126         except InvalidSelectorException as e:
#     127             raise e
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: Failed to decode response from marionette

# %%
i=0
list = [ ]
for item in card:

    name = strip(item.find(True, {'class':'_1z5je _10ZQX tvat-hotelName'}))
    
    loc = strip(item.find(True,{'class':'_3tICV'}))
    
    rating = strip(item.find(True,{'class':'tvat-ratingScore'}))

    rating_label_ = ''
    rating_label_ = strip(item.find(True,{'class':'_16hDy'})).split()

    if rating_label_ == []:
        rating_label = ''
    else:
        rating_label = rating_label_[0]
    # except:
    #     rating_label = ''

    number_of_reviews = ''
    number_of_reviews = strip(item.find(True,{'class':'_30os4'}))[1:-1]



    price = strip(item.find(True,{'class':'_22n9I tvat-primaryPrice'}))[3:]
    
    type = strip(item.find(True,{'class':'_3ohst Jewfo _2Vswb'}))
    
    # price_for= strip(item.find(True,{'class':'_4abc4c3d5 _7ee1c7d14'}))

    stars = item.find(True,{'class':'_1RoiH _1dIAz tvat-starRating _1Fq-V'})

    # city = kota.iloc[j,1]

    # province_name = kota.iloc[j,0]

    if stars == None:
        stars_count = ''
    elif len(stars) == 1:
        stars_count = ''
    else:
        stars_count=str(len(stars)-1)

    # href_tag= item.find('a', href=True)['href']

    list_in_list = [name,loc,rating,rating_label,number_of_reviews,price,type,stars_count]#,bed,price_for,stars_count,city,href_tag]
    
    list.append(list_in_list)
    #print(list_in_list)
    i=i+1
df = pd.DataFrame(list,columns= ['name','loc','rating','rating_label','number_of_reviews','price','type','stars_count'])
df.replace('', np.nan, inplace=True)
df.dropna(axis=0,how='all')
df
# Out:
#                                                   name  \
# 0                                 The Langham, Jakarta
# 1                         Hotel Mulia Senayan, Jakarta
# 2                              Ascott Sudirman Jakarta
# 3    MAY Property Apartment Kalibata City Tower Gah...
# 4                         Hotel GranDhika Iskandarsyah
# ..                                                 ...
# 621  2BR Cozy and Modern L'Avenue Apartment by Trav...
# 622                      2 BR Niffaro Park by Travelio
# 623                    Apartemen Kalibatacity By Dimas
# 624  2 Bedrooms Residence at Apartment Kalibata Cit...
# 625                                 Havenwood Senopati
#
#                                loc rating rating_label number_of_reviews  \
# 0           Senayan, South Jakarta    8.8   Impressive               193
# 1           Senayan, South Jakarta    8.7   Impressive              1377
# 2    Karet Semanggi, South Jakarta    8.6   Impressive              2040
# 3          Pancoran, South Jakarta    6.9         Good                11
# 4           Melawai, South Jakarta    8.6   Impressive              4671
# ..                             ...    ...          ...               ...
# 621        Pancoran, South Jakarta    NaN          NaN               NaN
# 622    East Pejaten, South Jakarta    8.0   Convenient                14
# 623        Kalibata, South Jakarta    NaN          NaN               NaN
# 624        Kalibata, South Jakarta    8.4   Impressive                33
# 625          Selong, South Jakarta    8.6   Impressive               233
#
#          price        type stars_count
# 0    3.484.800      Hotels           5
# 1    2.056.999      Hotels           5
# 2    1.359.600  Apartments           5
# 3      350.000  Apartments         NaN
# 4      720.000      Hotels           4
# ..         ...         ...         ...
# 621  2.018.755  Apartments         NaN
# 622    611.747  Apartments           1
# 623    317.058  Apartments           1
# 624    585.337  Apartments           1
# 625  4.221.772  Apartments           4
#
# [626 rows x 8 columns]

# %%
price = strip(item.find(True,{'class':'_22n9I tvat-primaryPrice'}))[3:]
price
# Out:
# '4.221.772'

# %%
# x = open("card.html","r")
# card=BeautifulSoup(x, 'html.parser')

card=BeautifulSoup(x, 'html.parser').find_all(True,{'class':'ztzlF _2nyWi'})

#card sudah di simpan di C:\Users\62811\Documents\Web Scraping Project (traveloka.com)

# %%
kota.iloc[103,1]
# Out:
# 'JAKARTA PUSAT'

# %%
#url link
my_url='https://www.traveloka.com/en-id/'


#calling web driver from its directory
s=Service(r'C:\Users\62811\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe') 

empty_list=[]
a = pd.DataFrame(empty_list,columns= ['name','loc','rating','rating_label','number_of_reviews','price','type','stars_count'])

cities=[kota.iloc[101,1],kota.iloc[103,1]]
x=''
for city in cities:
    driver = webdriver.Firefox(service=s)
    wait = WebDriverWait(driver, 30)
    driver.get(my_url)
    search_box = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[data-testid='autocomplete-field']"))).send_keys(city)

    #(wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name' and *contains(string(), %s)]"%city)))).click()
    auto_complete = wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name'][1]")))
    auto_complete.click()
    wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "[data-testid='search-submit-button']"))).click()



    while True:
        try:
            time.sleep(4)
            x = x + wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "_2qd8A"))).get_attribute('innerHTML') #find_elements_by_class_name("_7192d3184")
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID,"next-button"))).click()
            print("Clicked on  Next Page »")
        except TimeoutException:
            print("No more Next Page »")
            break
    driver.quit()
# Out:
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# No more Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# Clicked on  Next Page »
# No more Next Page »

# %%
card=BeautifulSoup(x, 'html.parser').find_all(True,{'class':'ztzlF _2nyWi'})

i=0
list = [ ]
for item in card:

    name = strip(item.find(True, {'class':'_1z5je _10ZQX tvat-hotelName'}))
    
    loc = strip(item.find(True,{'class':'_3tICV'}))
    
    rating = strip(item.find(True,{'class':'tvat-ratingScore'}))

    rating_label_ = ''
    rating_label_ = strip(item.find(True,{'class':'_16hDy'})).split()

    if rating_label_ == []:
        rating_label = ''
    else:
        rating_label = rating_label_[0]
    # except:
    #     rating_label = ''

    number_of_reviews = ''
    number_of_reviews = strip(item.find(True,{'class':'_30os4'}))[1:-1]



    price = strip(item.find(True,{'class':'_22n9I tvat-primaryPrice'}))[3:]
    
    type = strip(item.find(True,{'class':'_3ohst Jewfo _2Vswb'}))
    
    # price_for= strip(item.find(True,{'class':'_4abc4c3d5 _7ee1c7d14'}))

    stars = item.find(True,{'class':'_1RoiH _1dIAz tvat-starRating _1Fq-V'})

    # city = kota.iloc[j,1]

    # province_name = kota.iloc[j,0]

    if stars == None:
        stars_count = ''
    elif len(stars) == 1:
        stars_count = ''
    else:
        stars_count=str(len(stars)-1)

    # href_tag= item.find('a', href=True)['href']

    list_in_list = [name,loc,rating,rating_label,number_of_reviews,price,type,stars_count]#,bed,price_for,stars_count,city,href_tag]
    
    list.append(list_in_list)
    #print(list_in_list)
    i=i+1
df = pd.DataFrame(list,columns= ['name','loc','rating','rating_label','number_of_reviews','price','type','stars_count'])
df.replace('', np.nan, inplace=True)
df.dropna(axis=0,how='all')

append_df_to_excel(df, r"test_web_scraping_py.xlsx")

import winsound
duration = 1000  # milliseconds
freq = 300  # Hz
winsound.Beep(freq, duration)
# Out:
#                                                    name  \
# 0                                  The Langham, Jakarta
# 1                          Hotel Mulia Senayan, Jakarta
# 2                               Ascott Sudirman Jakarta
# 3     MAY Property Apartment Kalibata City Tower Gah...
# 4                          Hotel GranDhika Iskandarsyah
# ...                                                 ...
# 1152                            Residence JR Backpacker
# 1153                               Pramukajati Homestay
# 1154                                      Menteng House
# 1155                                       Antara Hotel
# 1156                                       Cemara Hotel
#
#                                 loc rating rating_label number_of_reviews  \
# 0            Senayan, South Jakarta    8.8   Impressive               193
# 1            Senayan, South Jakarta    8.7   Impressive              1377
# 2     Karet Semanggi, South Jakarta    8.6   Impressive              2040
# 3           Pancoran, South Jakarta    6.9         Good                11
# 4            Melawai, South Jakarta    8.6   Impressive              4671
# ...                             ...    ...          ...               ...
# 1152  Kampung Rawa, Central Jakarta    7.5   Convenient                37
# 1153        Kramat, Central Jakarta    7.7   Convenient               383
# 1154       Thamrin, Central Jakarta    8.5   Impressive               176
# 1155    Pasar Baru, Central Jakarta    7.7   Convenient               258
# 1156       Thamrin, Central Jakarta    8.3   Impressive              1903
#
#           price          type stars_count
# 0     3.484.800        Hotels           5
# 1     2.056.999        Hotels           5
# 2     1.359.600    Apartments           5
# 3       350.000    Apartments         NaN
# 4       720.000        Hotels           4
# ...         ...           ...         ...
# 1152    450.000     Homestays         NaN
# 1153    262.500  Guest Houses         NaN
# 1154    350.001  Guest Houses           1
# 1155    311.612        Hotels           3
# 1156    689.999        Hotels           3
#
# [1157 rows x 8 columns]

# %%
append_df_to_excel(df, r"test_web_scraping_py.xlsx")

# %%
data = pd.read_excel("test_web_scraping_py.xlsx")
data
# Out:
#       Unnamed: 0                           name                  loc  rating  \
# 0            NaN        eL Hotel Royale Bandung     Merdeka, Bandung     8.7
# 1            NaN  Grand Tjokro Premiere Bandung  Cihampelas, Bandung     8.6
# 2            NaN         The Trans Luxury Hotel    Buahbatu, Bandung     9.0
# 3            NaN                De Batara Hotel  Cihampelas, Bandung     8.2
# 4            NaN           Rumah Kembar Lembang     Lembang, Bandung     9.3
# ...          ...                            ...                  ...     ...
# 3877         NaN              Villa 360 Bandung     Lembang, Bandung     8.8
# 3878         NaN     Hannah Room - Khusus Putri        Dago, Bandung     8.5
# 3879         NaN  Villa DSK - Buah Batu Bandung    Cipagalo, Bandung     8.3
# 3880         NaN          La Fasa Syariah Hotel  Jatinangor, Bandung     8.1
# 3881         NaN           ALI2 Pondok Orange 2     Ciwidey, Bandung     8.9
#
#      rating_label  number_of_reviews         price       type  stars_count
# 0      Impressive            15577.0    Rp 900.000     Hotels          4.0
# 1      Impressive            15273.0    Rp 869.211     Hotels          4.0
# 2      Impressive             6178.0  Rp 3.302.750     Hotels          5.0
# 3      Convenient             2978.0    Rp 289.900     Hotels          3.0
# 4          Superb               14.0    Rp 875.000     Villas          NaN
# ...           ...                ...           ...        ...          ...
# 3877   Impressive               21.0     3.750.000     Villas          1.0
# 3878   Impressive              144.0       220.399  Homestays          NaN
# 3879   Impressive               11.0     1.799.999     Villas          2.0
# 3880   Convenient              239.0       850.000     Hotels          1.0
# 3881   Impressive               36.0       694.445  Homestays          1.0
#
# [3882 rows x 9 columns]

# %%
data.drop_duplicates(subset="name")
# Out:
#       Unnamed: 0                                               name  \
# 0            NaN                            eL Hotel Royale Bandung
# 1            NaN                      Grand Tjokro Premiere Bandung
# 2            NaN                             The Trans Luxury Hotel
# 3            NaN                                    De Batara Hotel
# 4            NaN                               Rumah Kembar Lembang
# ...          ...                                                ...
# 2645         NaN  Homey with Beautifully Designed 2BR Bassura Ci...
# 2646         NaN         Contemporary 2BR at Bassura City Apartment
# 2647         NaN   Simplicity Minimalist 2BR Bassura City Apartment
# 2701         NaN                    Sheraton Bandung Hotel & Towers
# 2709         NaN                 Courtyard by Marriott Bandung Dago
#
#                          loc  rating rating_label  number_of_reviews  \
# 0           Merdeka, Bandung     8.7   Impressive            15577.0
# 1        Cihampelas, Bandung     8.6   Impressive            15273.0
# 2          Buahbatu, Bandung     9.0   Impressive             6178.0
# 3        Cihampelas, Bandung     8.2   Convenient             2978.0
# 4           Lembang, Bandung     9.3       Superb               14.0
# ...                      ...     ...          ...                ...
# 2645  Cipinang, East Jakarta     NaN          NaN                NaN
# 2646  Cipinang, East Jakarta     NaN          NaN                NaN
# 2647  Cipinang, East Jakarta     NaN          NaN                NaN
# 2701      Dago Atas, Bandung     8.7   Impressive             2093.0
# 2709           Dago, Bandung     8.6   Impressive             2091.0
#
#              price        type  stars_count
# 0       Rp 900.000      Hotels          4.0
# 1       Rp 869.211      Hotels          4.0
# 2     Rp 3.302.750      Hotels          5.0
# 3       Rp 289.900      Hotels          3.0
# 4       Rp 875.000      Villas          NaN
# ...            ...         ...          ...
# 2645       512.126  Apartments          NaN
# 2646       573.784  Apartments          3.0
# 2647       492.119  Apartments          3.0
# 2701    11.020.800      Hotels          5.0
# 2709     1.562.461      Hotels          4.0
#
# [2375 rows x 9 columns]

# %%
a = pd.read_excel("test.xlsx")
a
# Out:
#                                        name  \
# 0                      OYO 2410 Intan Hotel
# 1                       The Royal IDI Hotel
# 2      Parkside Gayo Petro Hotel - Takengon
# 3             Grand Renggali Hotel Takengon
# 4                     Hotel Grand Bayu Hill
# ...                                     ...
# 19830                   Hotel Mahkota Beach
# 19831   Hotel Cendrawasih Kotaraja Jayapura
# 19832                          Hotel Delima
# 19833                     Hotel Agung Papua
# 19834                         Hotel Permata
#
#                                        loc  rating rating_label  \
# 0      Babul Makmur, Aceh Tenggara Regency     NaN          NaN
# 1           Darul Ihsan, East Aceh Regency     8.7   Impressive
# 2                   Takengon, Central Aceh     8.8   Impressive
# 3                       Central Aceh, Aceh     8.0   Convenient
# 4                  Kebayakan, Central Aceh     8.2   Convenient
# ...                                    ...     ...          ...
# 19830        South Jayapura, Jayapura City     7.7   Convenient
# 19831               Abepura, Jayapura City     7.0         Good
# 19832        South Jayapura, Jayapura City     7.7   Convenient
# 19833        South Jayapura, Jayapura City     8.3   Impressive
# 19834        North Jayapura, Jayapura City     7.1   Convenient
#
#        number_of_reviews    price    type  stars_count
# 0                    NaN  167.707  Hotels          NaN
# 1                   71.0  753.012  Hotels          3.0
# 2                   84.0  711.111  Hotels          3.0
# 3                  131.0      650  Hotels          3.0
# 4                   10.0      585  Hotels          4.0
# ...                  ...      ...     ...          ...
# 19830                5.0  352.941  Hotels          NaN
# 19831               35.0  336.000  Hotels          3.0
# 19832               32.0  598.290  Hotels          NaN
# 19833               50.0  895.315  Hotels          NaN
# 19834               52.0  686.274  Hotels          NaN
#
# [19835 rows x 8 columns]

# %%
from IPython.display import display, HTML

display(a)
# Out:
#                                        name  \
# 0                      OYO 2410 Intan Hotel
# 1                       The Royal IDI Hotel
# 2      Parkside Gayo Petro Hotel - Takengon
# 3             Grand Renggali Hotel Takengon
# 4                     Hotel Grand Bayu Hill
# ...                                     ...
# 19830                   Hotel Mahkota Beach
# 19831   Hotel Cendrawasih Kotaraja Jayapura
# 19832                          Hotel Delima
# 19833                     Hotel Agung Papua
# 19834                         Hotel Permata
#
#                                        loc  rating rating_label  \
# 0      Babul Makmur, Aceh Tenggara Regency     NaN          NaN
# 1           Darul Ihsan, East Aceh Regency     8.7   Impressive
# 2                   Takengon, Central Aceh     8.8   Impressive
# 3                       Central Aceh, Aceh     8.0   Convenient
# 4                  Kebayakan, Central Aceh     8.2   Convenient
# ...                                    ...     ...          ...
# 19830        South Jayapura, Jayapura City     7.7   Convenient
# 19831               Abepura, Jayapura City     7.0         Good
# 19832        South Jayapura, Jayapura City     7.7   Convenient
# 19833        South Jayapura, Jayapura City     8.3   Impressive
# 19834        North Jayapura, Jayapura City     7.1   Convenient
#
#        number_of_reviews    price    type  stars_count
# 0                    NaN  167.707  Hotels          NaN
# 1                   71.0  753.012  Hotels          3.0
# 2                   84.0  711.111  Hotels          3.0
# 3                  131.0      650  Hotels          3.0
# 4                   10.0      585  Hotels          4.0
# ...                  ...      ...     ...          ...
# 19830                5.0  352.941  Hotels          NaN
# 19831               35.0  336.000  Hotels          3.0
# 19832               32.0  598.290  Hotels          NaN
# 19833               50.0  895.315  Hotels          NaN
# 19834               52.0  686.274  Hotels          NaN
#
# [19835 rows x 8 columns]
