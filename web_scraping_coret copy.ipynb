# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys

import bs4
from bs4 import BeautifulSoup

import requests
import pandas as pd
import time
import numpy as np

# %%
#appending data frame to existing excel file
def append_df_to_excel(df, excel_path):
    df_excel = pd.read_excel(excel_path)
    result = pd.concat([df_excel, df], ignore_index=True)
    result.to_excel(excel_path, index=False)

# %%
# #reading provinces list
# read_province_list = open("jawa_bali.txt",'r')
# provinces=[]
# # # for _ in range(33): #skipping province
# # #     next(read_province_list)
# for province in read_province_list:
#     provinces.append(province.replace("\n", ", Indonesia").strip())

# # provinces[33]+=", Indonesia"
# # provinces = pd.read_excel(r"Indonesias_Hotel_List.xlsx",usecols=[2],skiprows=[0]).drop_duplicates().values.tolist()


# #provinces=[provinces[44]]
# print((provinces))

# %%
kota = pd.read_csv(r"Indonesian_Family_Life_Survey_4_Longitude_and_Latitude.csv", usecols=[5,6]).drop_duplicates()
len(kota)
for j in range(99,102):
    print(kota.iloc[j,1])
# Out:
# PANGKAL PINANG
# B A T A M
# JAKARTA SELATAN

# %%
#url link
my_url='https://www.traveloka.com/en-id/'


#calling web driver from its directory
s=Service(r'C:\Users\62811\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe') 


def strip(x):
    if x !=None:
        return   str(x.text.strip())
    else:
        return str('')

# %%
#url link
my_url='https://www.traveloka.com/en-id/'


#calling web driver from its directory
s=Service(r'C:\Users\62811\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe') 

city=kota.iloc[99,1]
driver = webdriver.Firefox(service=s)
wait = WebDriverWait(driver, 30)
driver.get(my_url)
search_box = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[data-testid='autocomplete-field']"))).send_keys(city)

#(wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name' and *contains(string(), %s)]"%city)))).click()
auto_complete = wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@data-testid='autocomplete-item-name'][1]")))
auto_complete.click()
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "[data-testid='search-submit-button']"))).click()



x=''
while True:
    try:
        time.sleep(4)
        x = x + wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "_2qd8A"))).get_attribute('innerHTML') #find_elements_by_class_name("_7192d3184")
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID,"next-button"))).click()
        print("Clicked on  Next Page »")
    except TimeoutException:
        print("No more Next Page »")
        break
driver.quit()



import winsound
duration = 1000  # milliseconds
freq = 300  # Hz
winsound.Beep(freq, duration)
# Out:
# No more Next Page »

# %%
# x = open("card.html","r")
# card=BeautifulSoup(x, 'html.parser')
card=BeautifulSoup(x, 'html.parser').find_all(True,{'class':'ztzlF _2nyWi'})
# len(card)

#card sudah di simpan di C:\Users\62811\Documents\Web Scraping Project (traveloka.com)

# %%
i=0
list = [ ]
for item in card:

    name = strip(item.find(True, {'class':'_1z5je _10ZQX tvat-hotelName'}))
    
    loc = strip(item.find(True,{'class':'_3tICV'}))
    
    rating = strip(item.find(True,{'class':'tvat-ratingScore'}))

    rating_label_ = ''
    rating_label_ = strip(item.find(True,{'class':'_16hDy'})).split()

    if rating_label_ == []:
        rating_label = ''
    else:
        rating_label = rating_label_[0]
    # except:
    #     rating_label = ''

    number_of_reviews = ''
    number_of_reviews = strip(item.find(True,{'class':'_30os4'}))[1:-1]



    price = strip(item.find(True,{'class':'_22n9I tvat-primaryPrice'}))
    
    type = strip(item.find(True,{'class':'_3ohst Jewfo _2Vswb'}))
    
    # price_for= strip(item.find(True,{'class':'_4abc4c3d5 _7ee1c7d14'}))

    stars = item.find(True,{'class':'_1RoiH _1dIAz tvat-starRating _1Fq-V'})

    # city = kota.iloc[j,1]

    # province_name = kota.iloc[j,0]

    if stars == None:
        stars_count = ''
    elif len(stars) == 1:
        stars_count = ''
    else:
        stars_count=str(len(stars)-1)

    # href_tag= item.find('a', href=True)['href']

    list_in_list = [name,loc,rating,rating_label,number_of_reviews,price,type,stars_count]#,bed,price_for,stars_count,city,href_tag]
    
    list.append(list_in_list)
    #print(list_in_list)
    i=i+1
df = pd.DataFrame(list,columns= ['name','loc','rating','rating_label','number_of_reviews','price','type','stars_count'])
df.replace('', np.nan, inplace=True)
df.dropna(axis=0,how='all')
# Out:
#                                             name  \
# 0       Novotel Bangka Hotel & Convention Centre
# 1          FOX HARRIS Hotel Pangkalpinang Bangka
# 2   Soll Marina Hotel & Conference Center Bangka
# 3                          Cordela Pangkalpinang
# 4                 Puri Oasis Hotel Pangkalpinang
# 5                              Bangka City Hotel
# 6                          Grand Manunggal Hotel
# 7        OYO 923 Penginapan Balai Sultan Syariah
# 8                            Puncak Budget Hotel
# 9                                   Hotel Aksi 2
# 10                             Grand Vella Hotel
# 11                                   Ren'z Hotel
# 12                       Pia Hotel Pangkalpinang
# 13                      OYO 1844 Bravo Residence
# 14                             OYO 1157 Ant Home
# 15                       Sun Hotel Pangkalpinang
# 16                            Hotel Golden Vella
# 17                    OYO 90072 Apri Inn Syariah
# 18                               Balitong Resort
# 19       OYO 923 Penginapan Balai Sultan Syariah
# 20                                 Terrace Hotel
# 21       OYO 923 Penginapan Balai Sultan Syariah
# 22                        SPOT ON 2389 Kostel 99
# 23               OYO 3438 Pasir Padi Inn Syariah
# 24                             Griya Tirta Hotel
#
#                               loc rating rating_label number_of_reviews  \
# 0     Koba Street, Pangkal Pinang    8.7   Impressive              2638
# 1        Girimaya, Pangkal Pinang    8.3   Impressive              1399
# 2     Koba Street, Pangkal Pinang    8.6   Impressive              3613
# 3      Taman Sari, Pangkal Pinang    8.5   Impressive              1745
# 4      Taman Sari, Pangkal Pinang    8.3   Impressive              1341
# 5     Bukit Intan, Pangkal Pinang    8.3   Impressive              1169
# 6   Pangkal Balam, Pangkal Pinang    8.1   Convenient                23
# 7      Gerunggang, Pangkal Pinang    7.7   Convenient                86
# 8      Taman Sari, Pangkal Pinang    8.2   Convenient               619
# 9         Rangkui, Pangkal Pinang    8.4   Impressive               257
# 10    Koba Street, Pangkal Pinang    7.9   Convenient               197
# 11    Bukit Intan, Pangkal Pinang    8.3   Impressive               497
# 12     Taman Sari, Pangkal Pinang    7.7   Convenient               570
# 13    Koba Street, Pangkal Pinang    8.1   Convenient               157
# 14    Bukit Intan, Pangkal Pinang    8.1   Convenient               277
# 15        Rangkui, Pangkal Pinang    8.3   Impressive               314
# 16     Taman Sari, Pangkal Pinang    7.7   Convenient               692
# 17          Gabek, Pangkal Pinang    8.1   Convenient                15
# 18    Bukit Intan, Pangkal Pinang    8.2   Convenient                35
# 19     Gerunggang, Pangkal Pinang    7.7   Convenient                86
# 20    Bukit Intan, Pangkal Pinang    NaN          NaN               NaN
# 21     Gerunggang, Pangkal Pinang    7.7   Convenient                86
# 22     Gerunggang, Pangkal Pinang    7.5   Convenient                41
# 23    Bukit Intan, Pangkal Pinang    6.3         Good                 5
# 24    Bukit Intan, Pangkal Pinang    8.0   Convenient               169
#
#          price       type stars_count
# 0   Rp 762.300     Hotels           4
# 1   Rp 470.000     Hotels           4
# 2   Rp 538.000     Hotels           3
# 3   Rp 450.527     Hotels           2
# 4   Rp 299.000     Hotels           1
# 5   Rp 325.000     Hotels           2
# 6   Rp 309.000     Hotels         NaN
# 7   Rp 154.409     Hotels         NaN
# 8   Rp 400.000     Hotels           2
# 9   Rp 230.000     Hotels           2
# 10  Rp 435.000     Hotels           3
# 11  Rp 398.000     Hotels           2
# 12  Rp 292.500     Hotels           3
# 13  Rp 136.539     Hotels           1
# 14  Rp 214.046     Hotels           2
# 15  Rp 436.000     Hotels           2
# 16  Rp 265.000     Hotels           2
# 17  Rp 231.562    Hostels         NaN
# 18  Rp 500.000    Resorts           2
# 19  Rp 154.409     Hotels         NaN
# 20  Rp 267.000     Hotels         NaN
# 21  Rp 154.409     Hotels         NaN
# 22  Rp 125.304     Hotels         NaN
# 23  Rp 179.593  Homestays         NaN
# 24  Rp 310.000     Hotels           1

# %%
f = open("card_bandung.html", "a")
f.write(str(card))
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21588/703091906.py in <module>
#       1 f = open("card_bandung.html", "a")
# ----> 2 f.write(str(card))
#       3 f.close()
#
# NameError: name 'card' is not defined
